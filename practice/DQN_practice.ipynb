# %%
import gym
import collections
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
# Hyperparameters
learning_rate = 0.0005
gamma = 0.98
buffer_limit = 50000
batch_size = 32

# %%
# replay buffer: 최신 5만개의 데이터(experience)를 갖고 있다가, 필요할 때마다 batch_size 만큼의 샘플을 뽑아서 제공
class ReplayBuffer():
    def __init__(self):
        self.buffer = collections.deque(maxlen=buffer_limit) # buffer 를 deque형 구조로 정의
        """
        deque: double-ended queue. 양방향에서 데이터를 처리할 수 있는 queue형 자료구조
               collections.deque()는 list와 비슷함
               collections.deque().append(): queue 오른쪽에 데이터를 추가
               size가 buffer_limit을 초과하면 자동으로 왼쪽(들어온지 가장 오래된) 데이터를 제거
        """

    def put(self, transition):
        self.buffer.append(transition)

    def sample(self, n):
        mini_batch = random.sample(self.buffer, n) # experience에서 크기가 n인 mini_batch 생성
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []

        for transition in mini_batch: # mini_batch안에서 s, a, r, s' 각각에 대한 리스트 생성
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append([done_mask])

            return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), torch.tensor(r_lst), torch.tensor(s_prime_lst, dtype=torch.float), torch.tensor(done_mask_lst)

    def size(self): # buffer 크기 반환
        return len(self.buffer)

# %%
class Qnetwork(nn.Module):
    def __init__(self):
        super(Qnetwork, self).__init__()
        self.fc1 = nn.Linear(4, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, 2)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x= self.fc3(x) # 마지막 layer는 Q value를 반환해야하기 때문에 양수만 반환하는 relu를 쓰면 안됨

        return x

    def sample_action(self, obs, epsilon): # epsilon-greedy policy
        out = self.forward(obs) # Q value
        coin = random.random()
        if coin < epsilon :
            return random.randint(0,1)
        else :
            return out.argmax().item()

# %%
import gym
import collections
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
#Hyperparameters
learning_rate = 0.0005
gamma         = 0.98
buffer_limit  = 50000
batch_size    = 32

# %%
class ReplayBuffer():
    def __init__(self):
        self.buffer = collections.deque(maxlen=buffer_limit)
        """
        collections.deque(): 좌우 양방향으로 데이터 출입이 가능한 자료구조.
        collections.deque().append(): 오른쪽에 데이터 추가.
        buffer_limit이 넘어가는 크기가 될 경우 왼쪽(가장 오래된) 데이터 제거
        """
    
    def put(self, transition):
        self.buffer.append(transition)
    
    def sample(self, n):
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []
        
        for transition in mini_batch:
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask_lst.append([done_mask])

        return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
               torch.tensor(r_lst), torch.tensor(s_prime_lst, dtype=torch.float), \
               torch.tensor(done_mask_lst)
    
    def size(self):
        return len(self.buffer)

# %%
class Qnetwork(nn.Module):
    def __init__(self):
        super(Qnetwork, self).__init__()
        self.fc1 = nn.Linear(4, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, 2)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x) # 마지막 layer에서는 실수 전체 범위인 Q value를 반환해야하므로 양수만 반환하는 relu를 사용하면 안됨
        return x
      
    def sample_action(self, obs, epsilon): # epsilon-greedy policy
        out = self.forward(obs)
        coin = random.random()
        if coin < epsilon:
            return random.randint(0,1)
        else : 
            return out.argmax().item()

# %%
def train(q, q_target, memory, optimizer):
    for i in range(10):
        s, a, r, s_prime, done_mask = memory.sample(batch_size) # experience에서 batch_size 만큼의 (s,a,r,s') 샘플 추출

        q_out = q(s) # Q network를 이용하여 s의 Q value 계산
        q_a = q_out.gather(1,a) # Q(s,a) 계산
        """
        Q value를 구현하는 방식은 크게 2가지
        1. (s,a)를 한꺼번에 받아 Q value를 반환
        2. s를 입력받아 모든 a에 대한 Q value를 반환
        위 방식은 2번 방식(DQN 논문에서 사용한 방식)
        근본적으로 두 방식의 차이는 없음
        """

        max_q_prime = q_target(s_prime).max(1)[0].unsqueeze(1) # 학습 target을 계산하기 위해 target network 사용
        target = r + gamma * max_q_prime * done_mask # TD target
        loss = F.smooth_l1_loss(q_a, target)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %%
def main():
    env = gym.make('CartPole-v1')
    q = Qnetwork()
    q_target = Qnetwork() # target network를 따로 구성
    q_target.load_state_dict(q.state_dict()) # q network와 동일한 parameter로 초기화 
    """
    state_dict(): a dict containing parameters and persistenet buffers
    load_state_dict(state_dict()): copies parameters and bufers from state_dict
    """
    memory = ReplayBuffer()

    print_interval = 20
    score = 0.0
    optimizer = optim.Adam(q.parameters(), lr=learning_rate) # target network는 학습 대상이 아니기 때문에 optimizer의 인자로 넘겨주지 않음 -> optimizer는 q network만 업데이트

    for n_epi in range(10000): # episode 10000개로 학습
        epsilon = max(0.01, 0.08 - 0.01*(n_epi/200)) #Linear annealing from 8% to 1%
        s = env.reset()
        done = False

        while not done: # episode 생성
            a = q.sample_action(torch.from_numpy(s).float(), epsilon) # Q network를 이용한 epsilon-greedy policy로 episode 생성      
            s_prime, r, done, info = env.step(a)
            done_mask = 0.0 if done else 1.0
            memory.put((s,a,r/100.0,s_prime, done_mask))
            """
            reward scale이 너무 커서 100으로 나눔.
            transition : (s,a,r,s')을 memory(experience)에 저장
            """ 
            s = s_prime

            score += r
            if done:
                break # terminal state에 도달하면 종료
            
        if memory.size()>2000:
            train(q, q_target, memory, optimizer)
            """
            episode 1회 종료 후, experience 크기가 2000 이상인 경우 parameter update 10회 시행
            deepmind DQN논문에서는 transition 1회 발생 시 마다 batch data를 이용한 parameter update 1회 시행하는 방식
            언제, 몇번 update 하는가는 다양하게 설정할 수 있는 듯.
            
            update 한 번 할 때 batch_size = 32개의 transition 데이터 사용
            """

        if n_epi%print_interval==0 and n_epi!=0:
            q_target.load_state_dict(q.state_dict()) # print_interval 마다 1번씩만 target network 업데이트
            print("n_episode :{}, score : {:.1f}, n_buffer : {}, eps : {:.1f}%".format(
                                                            n_epi, score/print_interval, memory.size(), epsilon*100))
            score = 0.0
    env.close()

# %%
main()
# Out:
# n_episode :20, score : 10.7, n_buffer : 213, eps : 7.9%
# n_episode :40, score : 10.1, n_buffer : 414, eps : 7.8%
# n_episode :60, score : 10.2, n_buffer : 618, eps : 7.7%
# n_episode :80, score : 10.2, n_buffer : 822, eps : 7.6%
# n_episode :100, score : 10.6, n_buffer : 1033, eps : 7.5%
# n_episode :120, score : 9.9, n_buffer : 1231, eps : 7.4%
# n_episode :140, score : 10.2, n_buffer : 1435, eps : 7.3%
# n_episode :160, score : 10.1, n_buffer : 1636, eps : 7.2%
# n_episode :180, score : 9.8, n_buffer : 1831, eps : 7.1%
# n_episode :200, score : 10.9, n_buffer : 2050, eps : 7.0%
# n_episode :220, score : 29.9, n_buffer : 2648, eps : 6.9%
# n_episode :240, score : 32.2, n_buffer : 3293, eps : 6.8%
# n_episode :260, score : 36.6, n_buffer : 4026, eps : 6.7%
# n_episode :280, score : 44.0, n_buffer : 4907, eps : 6.6%
# n_episode :300, score : 56.0, n_buffer : 6027, eps : 6.5%
# n_episode :320, score : 89.8, n_buffer : 7823, eps : 6.4%
# n_episode :340, score : 135.6, n_buffer : 10535, eps : 6.3%
# n_episode :360, score : 128.1, n_buffer : 13097, eps : 6.2%
# n_episode :380, score : 204.5, n_buffer : 17187, eps : 6.1%
# n_episode :400, score : 295.1, n_buffer : 23088, eps : 6.0%
# n_episode :420, score : 230.0, n_buffer : 27688, eps : 5.9%
# n_episode :440, score : 267.9, n_buffer : 33046, eps : 5.8%
# n_episode :460, score : 310.6, n_buffer : 39257, eps : 5.7%
# n_episode :480, score : 317.5, n_buffer : 45607, eps : 5.6%
# n_episode :500, score : 249.6, n_buffer : 50000, eps : 5.5%
# n_episode :520, score : 245.2, n_buffer : 50000, eps : 5.4%
# n_episode :540, score : 208.7, n_buffer : 50000, eps : 5.3%
# n_episode :560, score : 179.8, n_buffer : 50000, eps : 5.2%
# n_episode :580, score : 232.3, n_buffer : 50000, eps : 5.1%
# n_episode :600, score : 270.9, n_buffer : 50000, eps : 5.0%
# n_episode :620, score : 278.6, n_buffer : 50000, eps : 4.9%
# n_episode :640, score : 323.0, n_buffer : 50000, eps : 4.8%
# n_episode :660, score : 264.8, n_buffer : 50000, eps : 4.7%
# n_episode :680, score : 226.5, n_buffer : 50000, eps : 4.6%
# n_episode :700, score : 255.8, n_buffer : 50000, eps : 4.5%
# n_episode :720, score : 304.9, n_buffer : 50000, eps : 4.4%
# n_episode :740, score : 251.8, n_buffer : 50000, eps : 4.3%
# n_episode :760, score : 239.3, n_buffer : 50000, eps : 4.2%
# n_episode :780, score : 182.6, n_buffer : 50000, eps : 4.1%
# n_episode :800, score : 247.7, n_buffer : 50000, eps : 4.0%
# n_episode :820, score : 256.8, n_buffer : 50000, eps : 3.9%
# n_episode :840, score : 144.7, n_buffer : 50000, eps : 3.8%
# n_episode :860, score : 189.2, n_buffer : 50000, eps : 3.7%
# n_episode :880, score : 152.9, n_buffer : 50000, eps : 3.6%
# n_episode :900, score : 134.3, n_buffer : 50000, eps : 3.5%
# n_episode :920, score : 147.1, n_buffer : 50000, eps : 3.4%
# n_episode :940, score : 239.2, n_buffer : 50000, eps : 3.3%
# n_episode :960, score : 244.5, n_buffer : 50000, eps : 3.2%
# n_episode :980, score : 196.6, n_buffer : 50000, eps : 3.1%
# n_episode :1000, score : 238.9, n_buffer : 50000, eps : 3.0%
# n_episode :1020, score : 241.3, n_buffer : 50000, eps : 2.9%
# n_episode :1040, score : 227.1, n_buffer : 50000, eps : 2.8%
# n_episode :1060, score : 141.3, n_buffer : 50000, eps : 2.7%
# n_episode :1080, score : 166.1, n_buffer : 50000, eps : 2.6%
# n_episode :1100, score : 201.5, n_buffer : 50000, eps : 2.5%
# n_episode :1120, score : 181.8, n_buffer : 50000, eps : 2.4%
# n_episode :1140, score : 166.2, n_buffer : 50000, eps : 2.3%
# n_episode :1160, score : 208.9, n_buffer : 50000, eps : 2.2%
# n_episode :1180, score : 168.7, n_buffer : 50000, eps : 2.1%
# n_episode :1200, score : 198.8, n_buffer : 50000, eps : 2.0%
# n_episode :1220, score : 266.8, n_buffer : 50000, eps : 1.9%
# n_episode :1240, score : 244.7, n_buffer : 50000, eps : 1.8%
# n_episode :1260, score : 229.1, n_buffer : 50000, eps : 1.7%
# n_episode :1280, score : 247.5, n_buffer : 50000, eps : 1.6%
# n_episode :1300, score : 222.7, n_buffer : 50000, eps : 1.5%
# n_episode :1320, score : 191.7, n_buffer : 50000, eps : 1.4%
# n_episode :1340, score : 356.2, n_buffer : 50000, eps : 1.3%
# n_episode :1360, score : 264.4, n_buffer : 50000, eps : 1.2%
# n_episode :1380, score : 181.5, n_buffer : 50000, eps : 1.1%
# n_episode :1400, score : 178.6, n_buffer : 50000, eps : 1.0%
# n_episode :1420, score : 159.8, n_buffer : 50000, eps : 1.0%
# n_episode :1440, score : 234.7, n_buffer : 50000, eps : 1.0%
# n_episode :1460, score : 243.6, n_buffer : 50000, eps : 1.0%
# n_episode :1480, score : 312.7, n_buffer : 50000, eps : 1.0%
# n_episode :1500, score : 206.9, n_buffer : 50000, eps : 1.0%
# n_episode :1520, score : 243.1, n_buffer : 50000, eps : 1.0%
# n_episode :1540, score : 228.3, n_buffer : 50000, eps : 1.0%
# n_episode :1560, score : 319.0, n_buffer : 50000, eps : 1.0%
# n_episode :1580, score : 278.4, n_buffer : 50000, eps : 1.0%
# n_episode :1600, score : 196.0, n_buffer : 50000, eps : 1.0%
# n_episode :1620, score : 215.4, n_buffer : 50000, eps : 1.0%
# n_episode :1640, score : 187.9, n_buffer : 50000, eps : 1.0%
# n_episode :1660, score : 285.4, n_buffer : 50000, eps : 1.0%
# n_episode :1680, score : 386.9, n_buffer : 50000, eps : 1.0%
# n_episode :1700, score : 246.5, n_buffer : 50000, eps : 1.0%
# n_episode :1720, score : 387.1, n_buffer : 50000, eps : 1.0%
# n_episode :1740, score : 330.6, n_buffer : 50000, eps : 1.0%
# n_episode :1760, score : 303.1, n_buffer : 50000, eps : 1.0%
# n_episode :1780, score : 281.1, n_buffer : 50000, eps : 1.0%
# n_episode :1800, score : 311.6, n_buffer : 50000, eps : 1.0%
# n_episode :1820, score : 428.5, n_buffer : 50000, eps : 1.0%
# n_episode :1840, score : 293.1, n_buffer : 50000, eps : 1.0%
# n_episode :1860, score : 278.1, n_buffer : 50000, eps : 1.0%
# n_episode :1880, score : 262.6, n_buffer : 50000, eps : 1.0%
# n_episode :1900, score : 271.9, n_buffer : 50000, eps : 1.0%
# n_episode :1920, score : 222.8, n_buffer : 50000, eps : 1.0%
# n_episode :1940, score : 239.3, n_buffer : 50000, eps : 1.0%
# n_episode :1960, score : 192.0, n_buffer : 50000, eps : 1.0%
# n_episode :1980, score : 296.7, n_buffer : 50000, eps : 1.0%
# n_episode :2000, score : 309.8, n_buffer : 50000, eps : 1.0%
# n_episode :2020, score : 311.6, n_buffer : 50000, eps : 1.0%
# n_episode :2040, score : 271.4, n_buffer : 50000, eps : 1.0%
# n_episode :2060, score : 331.2, n_buffer : 50000, eps : 1.0%
# n_episode :2080, score : 240.3, n_buffer : 50000, eps : 1.0%
# n_episode :2100, score : 279.6, n_buffer : 50000, eps : 1.0%
# n_episode :2120, score : 232.7, n_buffer : 50000, eps : 1.0%
# n_episode :2140, score : 208.7, n_buffer : 50000, eps : 1.0%
# n_episode :2160, score : 166.1, n_buffer : 50000, eps : 1.0%
# n_episode :2180, score : 178.2, n_buffer : 50000, eps : 1.0%
# n_episode :2200, score : 175.2, n_buffer : 50000, eps : 1.0%
# n_episode :2220, score : 358.6, n_buffer : 50000, eps : 1.0%
# n_episode :2240, score : 222.9, n_buffer : 50000, eps : 1.0%
# n_episode :2260, score : 249.5, n_buffer : 50000, eps : 1.0%
# n_episode :2280, score : 392.1, n_buffer : 50000, eps : 1.0%
# n_episode :2300, score : 378.1, n_buffer : 50000, eps : 1.0%
# n_episode :2320, score : 394.1, n_buffer : 50000, eps : 1.0%
# n_episode :2340, score : 373.8, n_buffer : 50000, eps : 1.0%
# n_episode :2360, score : 297.4, n_buffer : 50000, eps : 1.0%
# n_episode :2380, score : 319.6, n_buffer : 50000, eps : 1.0%
# n_episode :2400, score : 298.4, n_buffer : 50000, eps : 1.0%
# n_episode :2420, score : 388.6, n_buffer : 50000, eps : 1.0%
# n_episode :2440, score : 345.1, n_buffer : 50000, eps : 1.0%
# n_episode :2460, score : 224.9, n_buffer : 50000, eps : 1.0%
# n_episode :2480, score : 124.0, n_buffer : 50000, eps : 1.0%
# n_episode :2500, score : 179.4, n_buffer : 50000, eps : 1.0%
# n_episode :2520, score : 243.9, n_buffer : 50000, eps : 1.0%
# n_episode :2540, score : 159.6, n_buffer : 50000, eps : 1.0%
# n_episode :2560, score : 155.3, n_buffer : 50000, eps : 1.0%
# n_episode :2580, score : 200.6, n_buffer : 50000, eps : 1.0%
# n_episode :2600, score : 188.1, n_buffer : 50000, eps : 1.0%
# n_episode :2620, score : 182.1, n_buffer : 50000, eps : 1.0%
# n_episode :2640, score : 175.2, n_buffer : 50000, eps : 1.0%
# n_episode :2660, score : 217.5, n_buffer : 50000, eps : 1.0%
# n_episode :2680, score : 187.0, n_buffer : 50000, eps : 1.0%
# n_episode :2700, score : 171.8, n_buffer : 50000, eps : 1.0%
# n_episode :2720, score : 156.7, n_buffer : 50000, eps : 1.0%
# n_episode :2740, score : 143.8, n_buffer : 50000, eps : 1.0%
# n_episode :2760, score : 152.8, n_buffer : 50000, eps : 1.0%
# n_episode :2780, score : 158.8, n_buffer : 50000, eps : 1.0%
# n_episode :2800, score : 168.7, n_buffer : 50000, eps : 1.0%
# n_episode :2820, score : 156.2, n_buffer : 50000, eps : 1.0%
# n_episode :2840, score : 157.2, n_buffer : 50000, eps : 1.0%
# n_episode :2860, score : 169.7, n_buffer : 50000, eps : 1.0%
# n_episode :2880, score : 159.9, n_buffer : 50000, eps : 1.0%
# n_episode :2900, score : 159.3, n_buffer : 50000, eps : 1.0%
# n_episode :2920, score : 153.7, n_buffer : 50000, eps : 1.0%
# n_episode :2940, score : 142.6, n_buffer : 50000, eps : 1.0%
# n_episode :2960, score : 184.2, n_buffer : 50000, eps : 1.0%
# n_episode :2980, score : 155.9, n_buffer : 50000, eps : 1.0%
# n_episode :3000, score : 138.3, n_buffer : 50000, eps : 1.0%
# n_episode :3020, score : 152.7, n_buffer : 50000, eps : 1.0%
# n_episode :3040, score : 161.8, n_buffer : 50000, eps : 1.0%
# n_episode :3060, score : 174.3, n_buffer : 50000, eps : 1.0%
# n_episode :3080, score : 130.1, n_buffer : 50000, eps : 1.0%
# n_episode :3100, score : 203.4, n_buffer : 50000, eps : 1.0%
# n_episode :3120, score : 213.7, n_buffer : 50000, eps : 1.0%
# n_episode :3140, score : 152.2, n_buffer : 50000, eps : 1.0%
# n_episode :3160, score : 161.9, n_buffer : 50000, eps : 1.0%
# n_episode :3180, score : 165.6, n_buffer : 50000, eps : 1.0%
# n_episode :3200, score : 166.6, n_buffer : 50000, eps : 1.0%
# n_episode :3220, score : 140.6, n_buffer : 50000, eps : 1.0%
# n_episode :3240, score : 196.4, n_buffer : 50000, eps : 1.0%
# n_episode :3260, score : 220.7, n_buffer : 50000, eps : 1.0%
# n_episode :3280, score : 227.2, n_buffer : 50000, eps : 1.0%
# n_episode :3300, score : 207.2, n_buffer : 50000, eps : 1.0%
# n_episode :3320, score : 206.5, n_buffer : 50000, eps : 1.0%
# n_episode :3340, score : 217.3, n_buffer : 50000, eps : 1.0%
# n_episode :3360, score : 120.5, n_buffer : 50000, eps : 1.0%
# n_episode :3380, score : 115.2, n_buffer : 50000, eps : 1.0%
# n_episode :3400, score : 138.2, n_buffer : 50000, eps : 1.0%
# n_episode :3420, score : 149.7, n_buffer : 50000, eps : 1.0%
# n_episode :3440, score : 199.1, n_buffer : 50000, eps : 1.0%
# n_episode :3460, score : 145.2, n_buffer : 50000, eps : 1.0%
# n_episode :3480, score : 132.8, n_buffer : 50000, eps : 1.0%
# n_episode :3500, score : 153.1, n_buffer : 50000, eps : 1.0%
# n_episode :3520, score : 137.8, n_buffer : 50000, eps : 1.0%
# n_episode :3540, score : 165.4, n_buffer : 50000, eps : 1.0%
# n_episode :3560, score : 191.2, n_buffer : 50000, eps : 1.0%
# n_episode :3580, score : 194.7, n_buffer : 50000, eps : 1.0%
# n_episode :3600, score : 210.8, n_buffer : 50000, eps : 1.0%
# n_episode :3620, score : 158.2, n_buffer : 50000, eps : 1.0%
# n_episode :3640, score : 129.4, n_buffer : 50000, eps : 1.0%
# n_episode :3660, score : 167.8, n_buffer : 50000, eps : 1.0%
# n_episode :3680, score : 199.9, n_buffer : 50000, eps : 1.0%
# n_episode :3700, score : 142.1, n_buffer : 50000, eps : 1.0%
# n_episode :3720, score : 204.8, n_buffer : 50000, eps : 1.0%
# n_episode :3740, score : 217.6, n_buffer : 50000, eps : 1.0%
# n_episode :3760, score : 247.3, n_buffer : 50000, eps : 1.0%
# n_episode :3780, score : 196.9, n_buffer : 50000, eps : 1.0%
# n_episode :3800, score : 185.0, n_buffer : 50000, eps : 1.0%
# n_episode :3820, score : 154.4, n_buffer : 50000, eps : 1.0%
# n_episode :3840, score : 151.4, n_buffer : 50000, eps : 1.0%
# n_episode :3860, score : 217.5, n_buffer : 50000, eps : 1.0%
# n_episode :3880, score : 194.8, n_buffer : 50000, eps : 1.0%
# n_episode :3900, score : 319.8, n_buffer : 50000, eps : 1.0%
# n_episode :3920, score : 361.8, n_buffer : 50000, eps : 1.0%
# n_episode :3940, score : 240.8, n_buffer : 50000, eps : 1.0%
# n_episode :3960, score : 179.9, n_buffer : 50000, eps : 1.0%
# n_episode :3980, score : 278.6, n_buffer : 50000, eps : 1.0%
# n_episode :4000, score : 309.4, n_buffer : 50000, eps : 1.0%
# n_episode :4020, score : 198.9, n_buffer : 50000, eps : 1.0%
# n_episode :4040, score : 279.6, n_buffer : 50000, eps : 1.0%
# n_episode :4060, score : 201.7, n_buffer : 50000, eps : 1.0%
# n_episode :4080, score : 226.8, n_buffer : 50000, eps : 1.0%
# n_episode :4100, score : 257.3, n_buffer : 50000, eps : 1.0%
# n_episode :4120, score : 301.0, n_buffer : 50000, eps : 1.0%
# n_episode :4140, score : 291.6, n_buffer : 50000, eps : 1.0%
# n_episode :4160, score : 383.1, n_buffer : 50000, eps : 1.0%
# n_episode :4180, score : 317.5, n_buffer : 50000, eps : 1.0%
# n_episode :4200, score : 365.4, n_buffer : 50000, eps : 1.0%
# n_episode :4220, score : 455.9, n_buffer : 50000, eps : 1.0%
# n_episode :4240, score : 473.4, n_buffer : 50000, eps : 1.0%
# n_episode :4260, score : 464.3, n_buffer : 50000, eps : 1.0%
# n_episode :4280, score : 400.0, n_buffer : 50000, eps : 1.0%
# n_episode :4300, score : 368.8, n_buffer : 50000, eps : 1.0%
# n_episode :4320, score : 297.8, n_buffer : 50000, eps : 1.0%
# n_episode :4340, score : 294.6, n_buffer : 50000, eps : 1.0%
# n_episode :4360, score : 171.1, n_buffer : 50000, eps : 1.0%
# n_episode :4380, score : 262.1, n_buffer : 50000, eps : 1.0%
# n_episode :4400, score : 304.5, n_buffer : 50000, eps : 1.0%
# n_episode :4420, score : 445.9, n_buffer : 50000, eps : 1.0%
# n_episode :4440, score : 460.1, n_buffer : 50000, eps : 1.0%
# n_episode :4460, score : 414.9, n_buffer : 50000, eps : 1.0%
# n_episode :4480, score : 378.6, n_buffer : 50000, eps : 1.0%
# n_episode :4500, score : 358.8, n_buffer : 50000, eps : 1.0%
# n_episode :4520, score : 370.9, n_buffer : 50000, eps : 1.0%
# n_episode :4540, score : 324.2, n_buffer : 50000, eps : 1.0%
# n_episode :4560, score : 323.9, n_buffer : 50000, eps : 1.0%
# n_episode :4580, score : 332.2, n_buffer : 50000, eps : 1.0%
# n_episode :4600, score : 267.0, n_buffer : 50000, eps : 1.0%
# n_episode :4620, score : 333.4, n_buffer : 50000, eps : 1.0%
# n_episode :4640, score : 379.4, n_buffer : 50000, eps : 1.0%
# n_episode :4660, score : 306.3, n_buffer : 50000, eps : 1.0%
# n_episode :4680, score : 344.3, n_buffer : 50000, eps : 1.0%
# n_episode :4700, score : 359.6, n_buffer : 50000, eps : 1.0%
# n_episode :4720, score : 442.1, n_buffer : 50000, eps : 1.0%
# n_episode :4740, score : 417.4, n_buffer : 50000, eps : 1.0%
# n_episode :4760, score : 418.2, n_buffer : 50000, eps : 1.0%
# n_episode :4780, score : 393.0, n_buffer : 50000, eps : 1.0%
# n_episode :4800, score : 444.9, n_buffer : 50000, eps : 1.0%
# n_episode :4820, score : 483.0, n_buffer : 50000, eps : 1.0%
# n_episode :4840, score : 498.8, n_buffer : 50000, eps : 1.0%
# n_episode :4860, score : 491.7, n_buffer : 50000, eps : 1.0%
# n_episode :4880, score : 465.1, n_buffer : 50000, eps : 1.0%
# n_episode :4900, score : 321.4, n_buffer : 50000, eps : 1.0%
# n_episode :4920, score : 463.9, n_buffer : 50000, eps : 1.0%
# n_episode :4940, score : 192.8, n_buffer : 50000, eps : 1.0%
# n_episode :4960, score : 27.1, n_buffer : 50000, eps : 1.0%
# n_episode :4980, score : 63.5, n_buffer : 50000, eps : 1.0%
# n_episode :5000, score : 446.6, n_buffer : 50000, eps : 1.0%
# n_episode :5020, score : 444.8, n_buffer : 50000, eps : 1.0%
# n_episode :5040, score : 287.4, n_buffer : 50000, eps : 1.0%
# n_episode :5060, score : 381.5, n_buffer : 50000, eps : 1.0%
# n_episode :5080, score : 452.8, n_buffer : 50000, eps : 1.0%
# n_episode :5100, score : 398.8, n_buffer : 50000, eps : 1.0%
# n_episode :5120, score : 187.8, n_buffer : 50000, eps : 1.0%
# n_episode :5140, score : 288.3, n_buffer : 50000, eps : 1.0%
# n_episode :5160, score : 215.6, n_buffer : 50000, eps : 1.0%
# n_episode :5180, score : 311.2, n_buffer : 50000, eps : 1.0%
# n_episode :5200, score : 427.1, n_buffer : 50000, eps : 1.0%
# n_episode :5220, score : 321.8, n_buffer : 50000, eps : 1.0%
# n_episode :5240, score : 466.4, n_buffer : 50000, eps : 1.0%
# n_episode :5260, score : 427.1, n_buffer : 50000, eps : 1.0%
# n_episode :5280, score : 440.2, n_buffer : 50000, eps : 1.0%
# n_episode :5300, score : 376.2, n_buffer : 50000, eps : 1.0%
# n_episode :5320, score : 303.9, n_buffer : 50000, eps : 1.0%
# n_episode :5340, score : 429.1, n_buffer : 50000, eps : 1.0%
# n_episode :5360, score : 398.1, n_buffer : 50000, eps : 1.0%
# n_episode :5380, score : 318.2, n_buffer : 50000, eps : 1.0%
# n_episode :5400, score : 329.4, n_buffer : 50000, eps : 1.0%
# n_episode :5420, score : 341.8, n_buffer : 50000, eps : 1.0%
# n_episode :5440, score : 378.1, n_buffer : 50000, eps : 1.0%
# n_episode :5460, score : 253.1, n_buffer : 50000, eps : 1.0%
# n_episode :5480, score : 415.8, n_buffer : 50000, eps : 1.0%
# n_episode :5500, score : 325.9, n_buffer : 50000, eps : 1.0%
# n_episode :5520, score : 267.2, n_buffer : 50000, eps : 1.0%
# n_episode :5540, score : 234.8, n_buffer : 50000, eps : 1.0%
# n_episode :5560, score : 171.8, n_buffer : 50000, eps : 1.0%
# n_episode :5580, score : 242.3, n_buffer : 50000, eps : 1.0%
# n_episode :5600, score : 378.9, n_buffer : 50000, eps : 1.0%
# n_episode :5620, score : 358.9, n_buffer : 50000, eps : 1.0%
# n_episode :5640, score : 479.0, n_buffer : 50000, eps : 1.0%
# n_episode :5660, score : 439.8, n_buffer : 50000, eps : 1.0%
# n_episode :5680, score : 361.8, n_buffer : 50000, eps : 1.0%
# n_episode :5700, score : 365.2, n_buffer : 50000, eps : 1.0%
# n_episode :5720, score : 197.4, n_buffer : 50000, eps : 1.0%
# n_episode :5740, score : 351.0, n_buffer : 50000, eps : 1.0%
# n_episode :5760, score : 257.8, n_buffer : 50000, eps : 1.0%
# n_episode :5780, score : 160.7, n_buffer : 50000, eps : 1.0%
# n_episode :5800, score : 196.2, n_buffer : 50000, eps : 1.0%
# n_episode :5820, score : 327.5, n_buffer : 50000, eps : 1.0%
# n_episode :5840, score : 259.1, n_buffer : 50000, eps : 1.0%
# n_episode :5860, score : 177.8, n_buffer : 50000, eps : 1.0%
# n_episode :5880, score : 209.8, n_buffer : 50000, eps : 1.0%
# n_episode :5900, score : 193.3, n_buffer : 50000, eps : 1.0%
# n_episode :5920, score : 174.5, n_buffer : 50000, eps : 1.0%
# n_episode :5940, score : 194.6, n_buffer : 50000, eps : 1.0%
# n_episode :5960, score : 190.6, n_buffer : 50000, eps : 1.0%
# n_episode :5980, score : 153.9, n_buffer : 50000, eps : 1.0%
# n_episode :6000, score : 109.0, n_buffer : 50000, eps : 1.0%
# n_episode :6020, score : 121.8, n_buffer : 50000, eps : 1.0%
# n_episode :6040, score : 134.8, n_buffer : 50000, eps : 1.0%
# n_episode :6060, score : 135.3, n_buffer : 50000, eps : 1.0%
# n_episode :6080, score : 150.1, n_buffer : 50000, eps : 1.0%
# n_episode :6100, score : 176.3, n_buffer : 50000, eps : 1.0%
# n_episode :6120, score : 225.3, n_buffer : 50000, eps : 1.0%
# n_episode :6140, score : 203.5, n_buffer : 50000, eps : 1.0%
# n_episode :6160, score : 208.7, n_buffer : 50000, eps : 1.0%
# n_episode :6180, score : 204.3, n_buffer : 50000, eps : 1.0%
# n_episode :6200, score : 195.5, n_buffer : 50000, eps : 1.0%
# n_episode :6220, score : 194.5, n_buffer : 50000, eps : 1.0%
# n_episode :6240, score : 190.3, n_buffer : 50000, eps : 1.0%
# n_episode :6260, score : 193.3, n_buffer : 50000, eps : 1.0%
# n_episode :6280, score : 205.1, n_buffer : 50000, eps : 1.0%
# n_episode :6300, score : 219.7, n_buffer : 50000, eps : 1.0%
# n_episode :6320, score : 201.2, n_buffer : 50000, eps : 1.0%
# n_episode :6340, score : 223.1, n_buffer : 50000, eps : 1.0%
# n_episode :6360, score : 224.5, n_buffer : 50000, eps : 1.0%
# n_episode :6380, score : 235.7, n_buffer : 50000, eps : 1.0%
# n_episode :6400, score : 247.3, n_buffer : 50000, eps : 1.0%
# n_episode :6420, score : 248.2, n_buffer : 50000, eps : 1.0%
# n_episode :6440, score : 249.1, n_buffer : 50000, eps : 1.0%
# n_episode :6460, score : 261.6, n_buffer : 50000, eps : 1.0%
# n_episode :6480, score : 237.7, n_buffer : 50000, eps : 1.0%
# n_episode :6500, score : 263.4, n_buffer : 50000, eps : 1.0%
# n_episode :6520, score : 292.0, n_buffer : 50000, eps : 1.0%
# n_episode :6540, score : 318.2, n_buffer : 50000, eps : 1.0%
# n_episode :6560, score : 289.6, n_buffer : 50000, eps : 1.0%
# n_episode :6580, score : 336.6, n_buffer : 50000, eps : 1.0%
# n_episode :6600, score : 349.1, n_buffer : 50000, eps : 1.0%
# n_episode :6620, score : 318.6, n_buffer : 50000, eps : 1.0%
# n_episode :6640, score : 343.1, n_buffer : 50000, eps : 1.0%
# n_episode :6660, score : 400.6, n_buffer : 50000, eps : 1.0%
# n_episode :6680, score : 364.6, n_buffer : 50000, eps : 1.0%
# n_episode :6700, score : 438.9, n_buffer : 50000, eps : 1.0%
# n_episode :6720, score : 313.4, n_buffer : 50000, eps : 1.0%
# n_episode :6740, score : 286.4, n_buffer : 50000, eps : 1.0%
# n_episode :6760, score : 370.7, n_buffer : 50000, eps : 1.0%
# n_episode :6780, score : 310.1, n_buffer : 50000, eps : 1.0%
# n_episode :6800, score : 286.7, n_buffer : 50000, eps : 1.0%
# n_episode :6820, score : 386.6, n_buffer : 50000, eps : 1.0%
# n_episode :6840, score : 322.9, n_buffer : 50000, eps : 1.0%
# n_episode :6860, score : 386.2, n_buffer : 50000, eps : 1.0%
# n_episode :6880, score : 287.5, n_buffer : 50000, eps : 1.0%
# n_episode :6900, score : 229.7, n_buffer : 50000, eps : 1.0%
# n_episode :6920, score : 284.1, n_buffer : 50000, eps : 1.0%
# n_episode :6940, score : 286.8, n_buffer : 50000, eps : 1.0%
# n_episode :6960, score : 292.2, n_buffer : 50000, eps : 1.0%
# n_episode :6980, score : 176.9, n_buffer : 50000, eps : 1.0%
# n_episode :7000, score : 115.7, n_buffer : 50000, eps : 1.0%
# n_episode :7020, score : 130.8, n_buffer : 50000, eps : 1.0%
# n_episode :7040, score : 124.5, n_buffer : 50000, eps : 1.0%
# n_episode :7060, score : 119.8, n_buffer : 50000, eps : 1.0%
# n_episode :7080, score : 119.5, n_buffer : 50000, eps : 1.0%
# n_episode :7100, score : 125.2, n_buffer : 50000, eps : 1.0%
# n_episode :7120, score : 82.0, n_buffer : 50000, eps : 1.0%
# n_episode :7140, score : 71.2, n_buffer : 50000, eps : 1.0%
# n_episode :7160, score : 145.3, n_buffer : 50000, eps : 1.0%
# n_episode :7180, score : 144.7, n_buffer : 50000, eps : 1.0%
# n_episode :7200, score : 147.4, n_buffer : 50000, eps : 1.0%
# n_episode :7220, score : 165.8, n_buffer : 50000, eps : 1.0%
# n_episode :7240, score : 150.2, n_buffer : 50000, eps : 1.0%
# n_episode :7260, score : 138.8, n_buffer : 50000, eps : 1.0%
# n_episode :7280, score : 128.4, n_buffer : 50000, eps : 1.0%
# n_episode :7300, score : 124.0, n_buffer : 50000, eps : 1.0%
# n_episode :7320, score : 129.2, n_buffer : 50000, eps : 1.0%
# n_episode :7340, score : 145.4, n_buffer : 50000, eps : 1.0%
# n_episode :7360, score : 156.4, n_buffer : 50000, eps : 1.0%
# n_episode :7380, score : 130.9, n_buffer : 50000, eps : 1.0%
# n_episode :7400, score : 236.7, n_buffer : 50000, eps : 1.0%
# n_episode :7420, score : 305.3, n_buffer : 50000, eps : 1.0%
# n_episode :7440, score : 262.3, n_buffer : 50000, eps : 1.0%
# n_episode :7460, score : 193.3, n_buffer : 50000, eps : 1.0%
# n_episode :7480, score : 296.9, n_buffer : 50000, eps : 1.0%
# n_episode :7500, score : 388.4, n_buffer : 50000, eps : 1.0%
# n_episode :7520, score : 441.0, n_buffer : 50000, eps : 1.0%
# n_episode :7540, score : 325.2, n_buffer : 50000, eps : 1.0%
# n_episode :7560, score : 265.6, n_buffer : 50000, eps : 1.0%
# n_episode :7580, score : 130.2, n_buffer : 50000, eps : 1.0%
# n_episode :7600, score : 132.9, n_buffer : 50000, eps : 1.0%
# n_episode :7620, score : 183.2, n_buffer : 50000, eps : 1.0%
# n_episode :7640, score : 223.7, n_buffer : 50000, eps : 1.0%
# n_episode :7660, score : 225.8, n_buffer : 50000, eps : 1.0%
# n_episode :7680, score : 204.7, n_buffer : 50000, eps : 1.0%
# n_episode :7700, score : 198.7, n_buffer : 50000, eps : 1.0%
# n_episode :7720, score : 178.8, n_buffer : 50000, eps : 1.0%
# n_episode :7740, score : 189.8, n_buffer : 50000, eps : 1.0%
# n_episode :7760, score : 174.4, n_buffer : 50000, eps : 1.0%
# n_episode :7780, score : 218.0, n_buffer : 50000, eps : 1.0%
# n_episode :7800, score : 239.6, n_buffer : 50000, eps : 1.0%
# n_episode :7820, score : 277.8, n_buffer : 50000, eps : 1.0%
# n_episode :7840, score : 227.8, n_buffer : 50000, eps : 1.0%
# n_episode :7860, score : 201.6, n_buffer : 50000, eps : 1.0%
# n_episode :7880, score : 338.4, n_buffer : 50000, eps : 1.0%
# n_episode :7900, score : 390.6, n_buffer : 50000, eps : 1.0%
# n_episode :7920, score : 408.2, n_buffer : 50000, eps : 1.0%
# n_episode :7940, score : 376.4, n_buffer : 50000, eps : 1.0%
# n_episode :7960, score : 341.2, n_buffer : 50000, eps : 1.0%
# n_episode :7980, score : 291.8, n_buffer : 50000, eps : 1.0%
# n_episode :8000, score : 290.8, n_buffer : 50000, eps : 1.0%
# n_episode :8020, score : 205.6, n_buffer : 50000, eps : 1.0%
# n_episode :8040, score : 276.1, n_buffer : 50000, eps : 1.0%
# n_episode :8060, score : 360.1, n_buffer : 50000, eps : 1.0%
# n_episode :8080, score : 258.9, n_buffer : 50000, eps : 1.0%
# n_episode :8100, score : 453.6, n_buffer : 50000, eps : 1.0%
# n_episode :8120, score : 403.6, n_buffer : 50000, eps : 1.0%
# n_episode :8140, score : 309.4, n_buffer : 50000, eps : 1.0%
# n_episode :8160, score : 313.8, n_buffer : 50000, eps : 1.0%
# n_episode :8180, score : 302.9, n_buffer : 50000, eps : 1.0%
# n_episode :8200, score : 257.4, n_buffer : 50000, eps : 1.0%
# n_episode :8220, score : 440.1, n_buffer : 50000, eps : 1.0%
# n_episode :8240, score : 307.1, n_buffer : 50000, eps : 1.0%
# n_episode :8260, score : 289.9, n_buffer : 50000, eps : 1.0%
# n_episode :8280, score : 470.7, n_buffer : 50000, eps : 1.0%
# n_episode :8300, score : 370.9, n_buffer : 50000, eps : 1.0%
# n_episode :8320, score : 367.0, n_buffer : 50000, eps : 1.0%
# n_episode :8340, score : 380.1, n_buffer : 50000, eps : 1.0%
# n_episode :8360, score : 262.9, n_buffer : 50000, eps : 1.0%
# n_episode :8380, score : 308.5, n_buffer : 50000, eps : 1.0%
# n_episode :8400, score : 338.3, n_buffer : 50000, eps : 1.0%
# n_episode :8420, score : 303.9, n_buffer : 50000, eps : 1.0%
# n_episode :8440, score : 415.5, n_buffer : 50000, eps : 1.0%
# n_episode :8460, score : 344.4, n_buffer : 50000, eps : 1.0%
# n_episode :8480, score : 363.1, n_buffer : 50000, eps : 1.0%
# n_episode :8500, score : 385.6, n_buffer : 50000, eps : 1.0%
# n_episode :8520, score : 430.6, n_buffer : 50000, eps : 1.0%
# n_episode :8540, score : 385.8, n_buffer : 50000, eps : 1.0%
# n_episode :8560, score : 370.3, n_buffer : 50000, eps : 1.0%
# n_episode :8580, score : 410.8, n_buffer : 50000, eps : 1.0%
# n_episode :8600, score : 385.9, n_buffer : 50000, eps : 1.0%
# n_episode :8620, score : 376.9, n_buffer : 50000, eps : 1.0%
# n_episode :8640, score : 374.1, n_buffer : 50000, eps : 1.0%
# n_episode :8660, score : 419.9, n_buffer : 50000, eps : 1.0%
# n_episode :8680, score : 419.8, n_buffer : 50000, eps : 1.0%
# n_episode :8700, score : 303.1, n_buffer : 50000, eps : 1.0%
# n_episode :8720, score : 438.1, n_buffer : 50000, eps : 1.0%
# n_episode :8740, score : 388.1, n_buffer : 50000, eps : 1.0%
# n_episode :8760, score : 434.2, n_buffer : 50000, eps : 1.0%
# n_episode :8780, score : 328.0, n_buffer : 50000, eps : 1.0%
# n_episode :8800, score : 425.2, n_buffer : 50000, eps : 1.0%
# n_episode :8820, score : 446.9, n_buffer : 50000, eps : 1.0%
# n_episode :8840, score : 416.9, n_buffer : 50000, eps : 1.0%
# n_episode :8860, score : 438.4, n_buffer : 50000, eps : 1.0%
# n_episode :8880, score : 394.4, n_buffer : 50000, eps : 1.0%
# n_episode :8900, score : 335.0, n_buffer : 50000, eps : 1.0%
# n_episode :8920, score : 440.4, n_buffer : 50000, eps : 1.0%
# n_episode :8940, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :8960, score : 427.1, n_buffer : 50000, eps : 1.0%
# n_episode :8980, score : 417.0, n_buffer : 50000, eps : 1.0%
# n_episode :9000, score : 421.1, n_buffer : 50000, eps : 1.0%
# n_episode :9020, score : 399.9, n_buffer : 50000, eps : 1.0%
# n_episode :9040, score : 416.1, n_buffer : 50000, eps : 1.0%
# n_episode :9060, score : 323.2, n_buffer : 50000, eps : 1.0%
# n_episode :9080, score : 309.6, n_buffer : 50000, eps : 1.0%
# n_episode :9100, score : 376.4, n_buffer : 50000, eps : 1.0%
# n_episode :9120, score : 433.7, n_buffer : 50000, eps : 1.0%
# n_episode :9140, score : 425.9, n_buffer : 50000, eps : 1.0%
# n_episode :9160, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :9180, score : 487.6, n_buffer : 50000, eps : 1.0%
# n_episode :9200, score : 491.0, n_buffer : 50000, eps : 1.0%
# n_episode :9220, score : 471.3, n_buffer : 50000, eps : 1.0%
# n_episode :9240, score : 467.9, n_buffer : 50000, eps : 1.0%
# n_episode :9260, score : 397.9, n_buffer : 50000, eps : 1.0%
# n_episode :9280, score : 420.9, n_buffer : 50000, eps : 1.0%
# n_episode :9300, score : 347.6, n_buffer : 50000, eps : 1.0%
# n_episode :9320, score : 278.6, n_buffer : 50000, eps : 1.0%
# n_episode :9340, score : 390.5, n_buffer : 50000, eps : 1.0%
# n_episode :9360, score : 467.8, n_buffer : 50000, eps : 1.0%
# n_episode :9380, score : 320.2, n_buffer : 50000, eps : 1.0%
# n_episode :9400, score : 438.2, n_buffer : 50000, eps : 1.0%
# n_episode :9420, score : 483.1, n_buffer : 50000, eps : 1.0%
# n_episode :9440, score : 463.8, n_buffer : 50000, eps : 1.0%
# n_episode :9460, score : 443.8, n_buffer : 50000, eps : 1.0%
# n_episode :9480, score : 428.4, n_buffer : 50000, eps : 1.0%
# n_episode :9500, score : 411.3, n_buffer : 50000, eps : 1.0%
# n_episode :9520, score : 430.2, n_buffer : 50000, eps : 1.0%
# n_episode :9540, score : 447.2, n_buffer : 50000, eps : 1.0%
# n_episode :9560, score : 464.2, n_buffer : 50000, eps : 1.0%
# n_episode :9580, score : 447.9, n_buffer : 50000, eps : 1.0%
# n_episode :9600, score : 449.6, n_buffer : 50000, eps : 1.0%
# n_episode :9620, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :9640, score : 315.9, n_buffer : 50000, eps : 1.0%
# n_episode :9660, score : 439.8, n_buffer : 50000, eps : 1.0%
# n_episode :9680, score : 441.2, n_buffer : 50000, eps : 1.0%
# n_episode :9700, score : 472.1, n_buffer : 50000, eps : 1.0%
# n_episode :9720, score : 464.2, n_buffer : 50000, eps : 1.0%
# n_episode :9740, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :9760, score : 438.9, n_buffer : 50000, eps : 1.0%
# n_episode :9780, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :9800, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :9820, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :9840, score : 482.0, n_buffer : 50000, eps : 1.0%
# n_episode :9860, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :9880, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :9900, score : 481.6, n_buffer : 50000, eps : 1.0%
# n_episode :9920, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :9940, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :9960, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :9980, score : 500.0, n_buffer : 50000, eps : 1.0%
