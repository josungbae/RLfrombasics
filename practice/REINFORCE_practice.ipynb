# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

# %%
# Hyperparameters
learning_rate = 0.0002
gamma = 0.98

# %%
class Policy(nn.Module):
    def __init__(self):
        super(Policy, self).__init__()
        self.data = []

        # policy network 구조: state variable 4개가 들어가 각 action(총 2개)에 대한 probability 도출
        self.fc1 = nn.Linear(4,128)
        self.fc2 = nn.Linear(128,2)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.softmax(self.fc2(x), dim=0)

        return x
    
    # policy network parameter update를 위한 episode 데이터에 item : (r, prob[a])를 추가
    def put_data(self,item): 
        self.data.append(item)

    # 쌓아놓은 episode 데이터를 이용하여 policy network 학습
    def train_net(self):
        R=0
        self.optimizer.zero_grad()

        """
        일반적인 pesudocode에서는 t=1 부터 t=T-1으로 순서대로 진행하며 parameter update를 진행.
        그러나 아래 코드에서는 t=T-1부터 T-1 역순으로 진행하며 cumulative return 인 Gt를 간단하게 계산하며 parameter update를 진행
        """
        for r, prob in self.data[::-1]: # data: 실제 sampling한 데이터(episode)
            R = r + gamma * R # episode를 역순으로 진행하기 때문에 이 방식으로 cumulative return을 차례대로 계산할 수 있음 
            """
            DQN에서 했던 것 처럼, optimizer를 통해 gradient ascent(discent)를 사용하기 위해서는 
            gradient 식을 넣는 것이 아니라, loss function을 입력해주어야함.
            REINFORCE에서 loss function에 해당하는 함수는 아래 함수. (미분하면 사용하고자 하는 gradient와 같아짐)
            gradient ascent이므로 -를 붙여줌.
            """
            loss = - R * torch.log(prob)

            """
            한 episode 안에서는 network update를 하지 않으므로, zero_grad()를 하지 않음.
            따라서 아래 loss.backward()는 gradient를 cumulative하게 계산하게 됨
            """
            loss.backward()

        self.optimizer.step() # 위에서 계산한 cumulative gradient를 통해 network update
        self.data = [] # 학습이 끝나면 episode data 초기화

# %%
def main():
    env = gym.make('CartPole-v1')
    pi = Policy()
    score = 0.0
    print_interval = 20

    # REINFORCE algorithm
    for n_epi in range(10000):
        # episode 생성 및 데이터 축적
        s = env.reset() # s: initial state
        done = False

        while not done:
            prob = pi(torch.from_numpy(s).float()) # prob: initial state s에서의 policy (action 별 prob.) = Policy(s)
            m = Categorical(prob) # Categorical: prob를 pdf로 변환
            a = m.sample() # 위에서 변환한 pdf에 따라 action 선택 -> torch.Tensor 형태로 출력 -> gradient가 발생되지 않도록 .numpy()나 .item()하여 사용
            s_prime, r, done, info = env.step(a.item()) # 다음 step 진행
            pi.put_data((r,prob[a])) # policy parameter update를 위한 episode에 (r, prob[a])를 추가. prob[a] = Policy(s)[a] = s에서 a를 취할 확률 : s에 대한 정보도 포함??
            s = s_prime
            score += r
        
        # episode 1개당 Policy().train_net() 1회 실행
        pi.train_net()

        if n_epi%print_interval==0 and n_epi!=0:
            print("# of episode :{}, avg score : {}".format(n_epi, score/print_interval))
            score = 0.0
    
    env.close()

# %%
main()
# Out:
# # of episode :20, avg score : 19.65
# # of episode :40, avg score : 17.1
# # of episode :60, avg score : 21.05
# # of episode :80, avg score : 25.2
# # of episode :100, avg score : 22.95
# # of episode :120, avg score : 22.05
# # of episode :140, avg score : 23.6
# # of episode :160, avg score : 23.95
# # of episode :180, avg score : 29.95
# # of episode :200, avg score : 29.9
# # of episode :220, avg score : 30.55
# # of episode :240, avg score : 27.15
# # of episode :260, avg score : 30.05
# # of episode :280, avg score : 35.2
# # of episode :300, avg score : 39.65
# # of episode :320, avg score : 41.25
# # of episode :340, avg score : 42.05
# # of episode :360, avg score : 36.4
# # of episode :380, avg score : 44.65
# # of episode :400, avg score : 46.7
# # of episode :420, avg score : 47.0
# # of episode :440, avg score : 53.65
# # of episode :460, avg score : 44.6
# # of episode :480, avg score : 45.1
# # of episode :500, avg score : 51.3
# # of episode :520, avg score : 52.0
# # of episode :540, avg score : 44.4
# # of episode :560, avg score : 47.9
# # of episode :580, avg score : 48.15
# # of episode :600, avg score : 49.4
# # of episode :620, avg score : 63.9
# # of episode :640, avg score : 61.3
# # of episode :660, avg score : 61.45
# # of episode :680, avg score : 55.8
# # of episode :700, avg score : 68.85
# # of episode :720, avg score : 68.9
# # of episode :740, avg score : 91.2
# # of episode :760, avg score : 54.35
# # of episode :780, avg score : 75.25
# # of episode :800, avg score : 70.15
# # of episode :820, avg score : 85.25
# # of episode :840, avg score : 98.5
# # of episode :860, avg score : 75.35
# # of episode :880, avg score : 73.45
# # of episode :900, avg score : 113.7
# # of episode :920, avg score : 101.45
# # of episode :940, avg score : 86.0
# # of episode :960, avg score : 107.9
# # of episode :980, avg score : 93.15
# # of episode :1000, avg score : 121.35
# # of episode :1020, avg score : 153.1
# # of episode :1040, avg score : 111.3
# # of episode :1060, avg score : 119.5
# # of episode :1080, avg score : 131.05
# # of episode :1100, avg score : 122.2
# # of episode :1120, avg score : 144.3
# # of episode :1140, avg score : 143.9
# # of episode :1160, avg score : 168.45
# # of episode :1180, avg score : 158.55
# # of episode :1200, avg score : 136.2
# # of episode :1220, avg score : 153.1
# # of episode :1240, avg score : 176.8
# # of episode :1260, avg score : 157.25
# # of episode :1280, avg score : 184.85
# # of episode :1300, avg score : 186.0
# # of episode :1320, avg score : 146.15
# # of episode :1340, avg score : 182.6
# # of episode :1360, avg score : 150.8
# # of episode :1380, avg score : 192.75
# # of episode :1400, avg score : 199.6
# # of episode :1420, avg score : 195.7
# # of episode :1440, avg score : 217.85
# # of episode :1460, avg score : 234.65
# # of episode :1480, avg score : 192.25
# # of episode :1500, avg score : 223.85
# # of episode :1520, avg score : 217.45
# # of episode :1540, avg score : 185.75
# # of episode :1560, avg score : 210.3
# # of episode :1580, avg score : 196.9
# # of episode :1600, avg score : 188.5
# # of episode :1620, avg score : 229.75
# # of episode :1640, avg score : 260.9
# # of episode :1660, avg score : 205.75
# # of episode :1680, avg score : 206.25
# # of episode :1700, avg score : 190.2
# # of episode :1720, avg score : 219.45
# # of episode :1740, avg score : 216.3
# # of episode :1760, avg score : 202.8
# # of episode :1780, avg score : 216.85
# # of episode :1800, avg score : 245.05
# # of episode :1820, avg score : 267.25
# # of episode :1840, avg score : 203.25
# # of episode :1860, avg score : 226.05
# # of episode :1880, avg score : 227.45
# # of episode :1900, avg score : 269.15
# # of episode :1920, avg score : 217.85
# # of episode :1940, avg score : 287.2
# # of episode :1960, avg score : 301.2
# # of episode :1980, avg score : 286.45
# # of episode :2000, avg score : 302.65
# # of episode :2020, avg score : 294.25
# # of episode :2040, avg score : 313.6
# # of episode :2060, avg score : 275.65
# # of episode :2080, avg score : 273.2
# # of episode :2100, avg score : 279.55
# # of episode :2120, avg score : 303.3
# # of episode :2140, avg score : 326.15
# # of episode :2160, avg score : 292.5
# # of episode :2180, avg score : 241.85
# # of episode :2200, avg score : 285.25
# # of episode :2220, avg score : 241.25
# # of episode :2240, avg score : 282.85
# # of episode :2260, avg score : 301.45
# # of episode :2280, avg score : 315.25
# # of episode :2300, avg score : 299.8
# # of episode :2320, avg score : 284.3
# # of episode :2340, avg score : 342.6
# # of episode :2360, avg score : 370.9
# # of episode :2380, avg score : 312.75
# # of episode :2400, avg score : 310.0
# # of episode :2420, avg score : 293.85
# # of episode :2440, avg score : 322.95
# # of episode :2460, avg score : 321.25
# # of episode :2480, avg score : 301.2
# # of episode :2500, avg score : 276.55
# # of episode :2520, avg score : 295.1
# # of episode :2540, avg score : 293.85
# # of episode :2560, avg score : 257.15
# # of episode :2580, avg score : 320.55
# # of episode :2600, avg score : 273.85
# # of episode :2620, avg score : 270.75
# # of episode :2640, avg score : 331.5
# # of episode :2660, avg score : 315.6
# # of episode :2680, avg score : 333.75
# # of episode :2700, avg score : 307.95
# # of episode :2720, avg score : 347.85
# # of episode :2740, avg score : 373.75
# # of episode :2760, avg score : 276.25
# # of episode :2780, avg score : 394.3
# # of episode :2800, avg score : 358.45
# # of episode :2820, avg score : 286.9
# # of episode :2840, avg score : 383.15
# # of episode :2860, avg score : 384.4
# # of episode :2880, avg score : 360.7
# # of episode :2900, avg score : 329.7
# # of episode :2920, avg score : 384.35
# # of episode :2940, avg score : 343.1
# # of episode :2960, avg score : 337.6
# # of episode :2980, avg score : 388.05
# # of episode :3000, avg score : 344.9
# # of episode :3020, avg score : 388.75
# # of episode :3040, avg score : 385.2
# # of episode :3060, avg score : 364.6
# # of episode :3080, avg score : 394.85
# # of episode :3100, avg score : 360.9
# # of episode :3120, avg score : 340.8
# # of episode :3140, avg score : 320.65
# # of episode :3160, avg score : 347.75
# # of episode :3180, avg score : 306.55
# # of episode :3200, avg score : 351.25
# # of episode :3220, avg score : 340.4
# # of episode :3240, avg score : 339.6
# # of episode :3260, avg score : 349.6
# # of episode :3280, avg score : 412.55
# # of episode :3300, avg score : 383.85
# # of episode :3320, avg score : 393.75
# # of episode :3340, avg score : 415.15
# # of episode :3360, avg score : 395.85
# # of episode :3380, avg score : 346.45
# # of episode :3400, avg score : 354.35
# # of episode :3420, avg score : 378.95
# # of episode :3440, avg score : 347.0
# # of episode :3460, avg score : 367.8
# # of episode :3480, avg score : 415.65
# # of episode :3500, avg score : 372.55
# # of episode :3520, avg score : 377.85
# # of episode :3540, avg score : 408.15
# # of episode :3560, avg score : 396.9
# # of episode :3580, avg score : 349.5
# # of episode :3600, avg score : 354.35
# # of episode :3620, avg score : 418.85
# # of episode :3640, avg score : 365.2
# # of episode :3660, avg score : 432.4
# # of episode :3680, avg score : 332.9
# # of episode :3700, avg score : 380.3
# # of episode :3720, avg score : 311.45
# # of episode :3740, avg score : 332.6
# # of episode :3760, avg score : 372.95
# # of episode :3780, avg score : 368.8
# # of episode :3800, avg score : 371.2
# # of episode :3820, avg score : 416.85
# # of episode :3840, avg score : 399.95
# # of episode :3860, avg score : 403.05
# # of episode :3880, avg score : 338.25
# # of episode :3900, avg score : 377.4
# # of episode :3920, avg score : 409.35
# # of episode :3940, avg score : 409.65
# # of episode :3960, avg score : 419.45
# # of episode :3980, avg score : 349.3
# # of episode :4000, avg score : 360.45
# # of episode :4020, avg score : 412.55
# # of episode :4040, avg score : 398.0
# # of episode :4060, avg score : 424.15
# # of episode :4080, avg score : 380.4
# # of episode :4100, avg score : 385.2
# # of episode :4120, avg score : 312.85
# # of episode :4140, avg score : 366.0
# # of episode :4160, avg score : 380.05
# # of episode :4180, avg score : 364.65
# # of episode :4200, avg score : 353.95
# # of episode :4220, avg score : 320.05
# # of episode :4240, avg score : 383.35
# # of episode :4260, avg score : 397.4
# # of episode :4280, avg score : 375.8
# # of episode :4300, avg score : 389.45
# # of episode :4320, avg score : 344.05
# # of episode :4340, avg score : 353.6
# # of episode :4360, avg score : 355.9
# # of episode :4380, avg score : 374.65
# # of episode :4400, avg score : 348.85
# # of episode :4420, avg score : 384.2
# # of episode :4440, avg score : 410.8
# # of episode :4460, avg score : 305.05
# # of episode :4480, avg score : 364.35
# # of episode :4500, avg score : 323.0
# # of episode :4520, avg score : 358.6
# # of episode :4540, avg score : 360.55
# # of episode :4560, avg score : 379.7
# # of episode :4580, avg score : 399.4
# # of episode :4600, avg score : 422.65
# # of episode :4620, avg score : 385.7
# # of episode :4640, avg score : 414.45
# # of episode :4660, avg score : 378.25
# # of episode :4680, avg score : 432.55
# # of episode :4700, avg score : 416.4
# # of episode :4720, avg score : 438.5
# # of episode :4740, avg score : 453.75
# # of episode :4760, avg score : 421.55
# # of episode :4780, avg score : 369.45
# # of episode :4800, avg score : 407.8
# # of episode :4820, avg score : 433.4
# # of episode :4840, avg score : 439.05
# # of episode :4860, avg score : 414.45
# # of episode :4880, avg score : 392.5
# # of episode :4900, avg score : 351.75
# # of episode :4920, avg score : 366.75
# # of episode :4940, avg score : 418.0
# # of episode :4960, avg score : 379.15
# # of episode :4980, avg score : 307.2
# # of episode :5000, avg score : 393.1
# # of episode :5020, avg score : 462.5
# # of episode :5040, avg score : 449.3
# # of episode :5060, avg score : 437.8
# # of episode :5080, avg score : 424.15
# # of episode :5100, avg score : 407.8
# # of episode :5120, avg score : 367.8
# # of episode :5140, avg score : 434.45
# # of episode :5160, avg score : 412.9
# # of episode :5180, avg score : 440.25
# # of episode :5200, avg score : 453.1
# # of episode :5220, avg score : 441.25
# # of episode :5240, avg score : 446.05
# # of episode :5260, avg score : 445.65
# # of episode :5280, avg score : 447.3
# # of episode :5300, avg score : 470.2
# # of episode :5320, avg score : 442.55
# # of episode :5340, avg score : 481.65
# # of episode :5360, avg score : 461.3
# # of episode :5380, avg score : 456.2
# # of episode :5400, avg score : 476.65
# # of episode :5420, avg score : 445.5
# # of episode :5440, avg score : 433.4
# # of episode :5460, avg score : 454.85
# # of episode :5480, avg score : 412.35
# # of episode :5500, avg score : 394.05
# # of episode :5520, avg score : 412.6
# # of episode :5540, avg score : 425.95
# # of episode :5560, avg score : 434.6
# # of episode :5580, avg score : 416.55
# # of episode :5600, avg score : 406.8
# # of episode :5620, avg score : 385.7
# # of episode :5640, avg score : 483.15
# # of episode :5660, avg score : 427.55
# # of episode :5680, avg score : 493.3
# # of episode :5700, avg score : 455.15
# # of episode :5720, avg score : 441.75
# # of episode :5740, avg score : 453.4
# # of episode :5760, avg score : 469.75
# # of episode :5780, avg score : 453.8
# # of episode :5800, avg score : 429.8
# # of episode :5820, avg score : 451.6
# # of episode :5840, avg score : 448.95
# # of episode :5860, avg score : 446.7
# # of episode :5880, avg score : 449.45
# # of episode :5900, avg score : 459.45
# # of episode :5920, avg score : 494.45
# # of episode :5940, avg score : 462.0
# # of episode :5960, avg score : 486.2
# # of episode :5980, avg score : 436.5
# # of episode :6000, avg score : 452.1
# # of episode :6020, avg score : 435.65
# # of episode :6040, avg score : 407.3
# # of episode :6060, avg score : 414.2
# # of episode :6080, avg score : 430.9
# # of episode :6100, avg score : 379.55
# # of episode :6120, avg score : 433.25
# # of episode :6140, avg score : 415.25
# # of episode :6160, avg score : 384.1
# # of episode :6180, avg score : 381.7
# # of episode :6200, avg score : 473.1
# # of episode :6220, avg score : 484.75
# # of episode :6240, avg score : 464.2
# # of episode :6260, avg score : 463.95
# # of episode :6280, avg score : 465.3
# # of episode :6300, avg score : 454.35
# # of episode :6320, avg score : 449.05
# # of episode :6340, avg score : 455.9
# # of episode :6360, avg score : 441.1
# # of episode :6380, avg score : 422.85
# # of episode :6400, avg score : 402.6
# # of episode :6420, avg score : 443.7
# # of episode :6440, avg score : 463.55
# # of episode :6460, avg score : 438.4
# # of episode :6480, avg score : 492.9
# # of episode :6500, avg score : 456.5
# # of episode :6520, avg score : 495.2
# # of episode :6540, avg score : 494.5
# # of episode :6560, avg score : 466.0
# # of episode :6580, avg score : 496.3
# # of episode :6600, avg score : 464.4
# # of episode :6620, avg score : 488.55
# # of episode :6640, avg score : 450.8
# # of episode :6660, avg score : 462.6
# # of episode :6680, avg score : 445.5
# # of episode :6700, avg score : 477.3
# # of episode :6720, avg score : 493.45
# # of episode :6740, avg score : 446.25
# # of episode :6760, avg score : 425.1
# # of episode :6780, avg score : 420.25
# # of episode :6800, avg score : 367.65
# # of episode :6820, avg score : 396.75
# # of episode :6840, avg score : 430.75
# # of episode :6860, avg score : 449.3
# # of episode :6880, avg score : 467.7
# # of episode :6900, avg score : 472.45
# # of episode :6920, avg score : 458.3
# # of episode :6940, avg score : 464.5
# # of episode :6960, avg score : 473.6
# # of episode :6980, avg score : 465.8
# # of episode :7000, avg score : 456.85
# # of episode :7020, avg score : 458.7
# # of episode :7040, avg score : 468.95
# # of episode :7060, avg score : 467.75
# # of episode :7080, avg score : 432.05
# # of episode :7100, avg score : 417.9
# # of episode :7120, avg score : 410.7
# # of episode :7140, avg score : 442.2
# # of episode :7160, avg score : 460.6
# # of episode :7180, avg score : 436.55
# # of episode :7200, avg score : 435.45
# # of episode :7220, avg score : 480.6
# # of episode :7240, avg score : 416.05
# # of episode :7260, avg score : 447.85
# # of episode :7280, avg score : 463.8
# # of episode :7300, avg score : 452.95
# # of episode :7320, avg score : 428.55
# # of episode :7340, avg score : 440.75
# # of episode :7360, avg score : 439.55
# # of episode :7380, avg score : 427.25
# # of episode :7400, avg score : 449.75
# # of episode :7420, avg score : 419.5
# # of episode :7440, avg score : 444.5
# # of episode :7460, avg score : 410.4
# # of episode :7480, avg score : 361.35
# # of episode :7500, avg score : 338.6
# # of episode :7520, avg score : 358.65
# # of episode :7540, avg score : 397.0
# # of episode :7560, avg score : 395.35
# # of episode :7580, avg score : 405.95
# # of episode :7600, avg score : 425.7
# # of episode :7620, avg score : 466.4
# # of episode :7640, avg score : 435.35
# # of episode :7660, avg score : 472.1
# # of episode :7680, avg score : 435.05
# # of episode :7700, avg score : 411.7
# # of episode :7720, avg score : 422.3
# # of episode :7740, avg score : 420.9
# # of episode :7760, avg score : 387.15
# # of episode :7780, avg score : 387.05
# # of episode :7800, avg score : 380.0
# # of episode :7820, avg score : 419.7
# # of episode :7840, avg score : 432.05
# # of episode :7860, avg score : 408.65
# # of episode :7880, avg score : 419.35
# # of episode :7900, avg score : 432.0
# # of episode :7920, avg score : 438.95
# # of episode :7940, avg score : 435.85
# # of episode :7960, avg score : 413.25
# # of episode :7980, avg score : 488.05
# # of episode :8000, avg score : 472.0
# # of episode :8020, avg score : 484.8
# # of episode :8040, avg score : 482.3
# # of episode :8060, avg score : 464.55
# # of episode :8080, avg score : 466.9
# # of episode :8100, avg score : 454.9
# # of episode :8120, avg score : 497.0
# # of episode :8140, avg score : 467.7
# # of episode :8160, avg score : 470.95
# # of episode :8180, avg score : 475.85
# # of episode :8200, avg score : 484.75
# # of episode :8220, avg score : 487.25
# # of episode :8240, avg score : 444.6
# # of episode :8260, avg score : 480.6
# # of episode :8280, avg score : 456.6
# # of episode :8300, avg score : 478.65
# # of episode :8320, avg score : 453.65
# # of episode :8340, avg score : 454.45
# # of episode :8360, avg score : 472.55
# # of episode :8380, avg score : 488.7
# # of episode :8400, avg score : 492.8
# # of episode :8420, avg score : 474.35
# # of episode :8440, avg score : 475.8
# # of episode :8460, avg score : 500.0
# # of episode :8480, avg score : 467.25
# # of episode :8500, avg score : 495.45
# # of episode :8520, avg score : 490.7
# # of episode :8540, avg score : 480.05
# # of episode :8560, avg score : 479.55
# # of episode :8580, avg score : 494.85
# # of episode :8600, avg score : 488.0
# # of episode :8620, avg score : 499.5
# # of episode :8640, avg score : 468.6
# # of episode :8660, avg score : 487.4
# # of episode :8680, avg score : 472.6
# # of episode :8700, avg score : 479.0
# # of episode :8720, avg score : 486.15
# # of episode :8740, avg score : 494.65
# # of episode :8760, avg score : 500.0
# # of episode :8780, avg score : 500.0
# # of episode :8800, avg score : 500.0
# # of episode :8820, avg score : 495.95
# # of episode :8840, avg score : 469.25
# # of episode :8860, avg score : 496.75
# # of episode :8880, avg score : 482.3
# # of episode :8900, avg score : 483.85
# # of episode :8920, avg score : 500.0
# # of episode :8940, avg score : 500.0
# # of episode :8960, avg score : 500.0
# # of episode :8980, avg score : 492.6
# # of episode :9000, avg score : 482.45
# # of episode :9020, avg score : 500.0
# # of episode :9040, avg score : 465.7
# # of episode :9060, avg score : 487.0
# # of episode :9080, avg score : 468.95
# # of episode :9100, avg score : 500.0
# # of episode :9120, avg score : 500.0
# # of episode :9140, avg score : 488.2
# # of episode :9160, avg score : 482.05
# # of episode :9180, avg score : 480.6
# # of episode :9200, avg score : 500.0
# # of episode :9220, avg score : 496.1
# # of episode :9240, avg score : 495.1
# # of episode :9260, avg score : 476.95
# # of episode :9280, avg score : 442.2
# # of episode :9300, avg score : 449.3
# # of episode :9320, avg score : 482.55
# # of episode :9340, avg score : 478.55
# # of episode :9360, avg score : 471.9
# # of episode :9380, avg score : 448.6
# # of episode :9400, avg score : 500.0
# # of episode :9420, avg score : 493.0
# # of episode :9440, avg score : 489.0
# # of episode :9460, avg score : 482.1
# # of episode :9480, avg score : 473.3
# # of episode :9500, avg score : 478.1
# # of episode :9520, avg score : 499.05
# # of episode :9540, avg score : 468.0
# # of episode :9560, avg score : 485.15
# # of episode :9580, avg score : 479.15
# # of episode :9600, avg score : 491.05
# # of episode :9620, avg score : 491.6
# # of episode :9640, avg score : 471.55
# # of episode :9660, avg score : 470.65
# # of episode :9680, avg score : 490.05
# # of episode :9700, avg score : 477.1
# # of episode :9720, avg score : 481.65
# # of episode :9740, avg score : 464.8
# # of episode :9760, avg score : 494.65
# # of episode :9780, avg score : 470.4
# # of episode :9800, avg score : 493.7
# # of episode :9820, avg score : 470.95
# # of episode :9840, avg score : 465.15
# # of episode :9860, avg score : 487.6
# # of episode :9880, avg score : 475.4
# # of episode :9900, avg score : 473.05
# # of episode :9920, avg score : 479.4
# # of episode :9940, avg score : 475.35
# # of episode :9960, avg score : 494.0
# # of episode :9980, avg score : 472.55
